# %% [markdown]
# > # Music Genre and Composer Classification Using Deep Learning
#  ![Music Genre and Composer Classification Using Deep Learning](data/header.png)

# %% [markdown]
# **University of San Diego**
# AAI-511: Neural Networks and Deep Learning
#
# ---
# **Professor**: Rod Albuyeh
# **Section**: 5
# **Group**: 2
# **Contributors**:
# - Ashley Moore
# - Kevin Pooler
# - Swapnil Patil
#
#
# August, 2025
#
# ---

# %% [markdown]
# <a id='Index'></a>
# # Index
#
# 1. [Introduction](#introduction)
# 1. [Objective](#objective)
# 1. [Dataset](#dataset)
# 1. [Data Cleaning and Preprocessing](#datacleaning)
# 1. [Feature Extraction](#featureextraction)
# 1. [Exploratory Data Analysis](#exploratory)
# 1. [Model Building](#modelbuilding):
#     - [LSTM](#modelbuildinglstm)
#     - [CNN](#modelbuildingcnn)
# 1. [Model Training](#modeltraining)
# 1. [Model Evaluation](#modelevaluation)
# 1. [Model Optimization](#modeloptimization)
# 1. [Deployment](#deployment)
# 1. [Conclusion](#conclusion)
# 1. [Recommendations](#recommendations)
# 1. [Next Steps](#nextsteps)
# 1. [References](#references)
#
# ### Streamlit Application
# [Application URL](https://musicai.streamlit.app/)

# %% [markdown]
# <a id='introduction'></a>
# # 1. Introduction: <a href="#Index" style="font-size:25px;">&#8679;</a>
#
# ---

# %% [markdown]
# Music is a form of art that is ubiquitous and has a rich history. Different composers have created music with their unique styles and compositions. However, identifying the composer of a particular piece of music can be a challenging task, especially for novice musicians or listeners. The proposed project aims to use deep learning techniques to identify the composer of a given piece of music accurately.

# %% [markdown]
# <a id='objective'></a>
# # 2. Objective: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# #### Problem Statement
#
# The primary objective of this project is to develop a deep learning model that can predict the composer of a given musical score accurately. The project aims to accomplish this objective by using two deep learning techniques: Long Short-Term Memory (LSTM) and Convolutional Neural Network (CNN).

# %% [markdown]
# <a id='dataset'></a>
# # 3. Dataset:
# ---

# %% [markdown]
# The project will use a dataset consisting of musical scores from various composers.
#
# https://www.kaggle.com/datasets/blanderbuss/midi-classic-music
#
# The dataset contains the midi files of compositions from well-known classical composers like Bach, Beethoven, Chopin, and Mozart. The dataset should be labeled with the name of the composer for each score. Please only do your prediction only for below composers, therefore you need to select the required composers from the given dataset above.
#
# 1. Bach
# 1. Beethoven
# 1. Chopin
# 1. Mozart

# %% [markdown]
# <a id='datacleaning'></a>
# # 4. Data Cleaning and Pre-processing: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %%
# %pip install -r requirements.txt
# %load_ext autoreload
# %autoreload 2
# Out:
# Requirement already satisfied: numpy>=1.21.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: pandas>=1.3.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: matplotlib>=3.4.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 5)) (1.7.0)
# Requirement already satisfied: tensorflow>=2.8.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 6)) (2.19.0)
# Requirement already satisfied: music21>=8.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 7)) (9.7.1)
# Requirement already satisfied: jupyter>=1.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: ipykernel>=6.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 9)) (6.29.5)
# Requirement already satisfied: plotly>=5.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 10)) (6.2.0)
# Requirement already satisfied: tqdm>=4.62.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: h5py>=3.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 12)) (3.14.0)
# Requirement already satisfied: keras>=2.8.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 13)) (3.10.0)
# Requirement already satisfied: librosa>=0.8.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 14)) (0.11.0)
# Requirement already satisfied: joblib>=1.0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from -r requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: pillow>=8 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: scipy>=1.8.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (5.29.5)
# Requirement already satisfied: six>=1.12.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (1.73.1)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (1.17.2)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (2.19.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.31.0)
# Requirement already satisfied: setuptools in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (63.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (4.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorflow>=2.8.0->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: more-itertools in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from music21>=8.1.0->-r requirements.txt (line 7)) (10.7.0)
# Requirement already satisfied: webcolors>=1.5 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from music21>=8.1.0->-r requirements.txt (line 7)) (24.11.1)
# Requirement already satisfied: jsonpickle in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from music21>=8.1.0->-r requirements.txt (line 7)) (4.1.1)
# Requirement already satisfied: chardet in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from music21>=8.1.0->-r requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: jupyter-console in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 8)) (6.6.3)
# Requirement already satisfied: jupyterlab in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 8)) (4.4.4)
# Requirement already satisfied: ipywidgets in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: notebook in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 8)) (7.4.4)
# Requirement already satisfied: nbconvert in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter>=1.0.0->-r requirements.txt (line 8)) (7.16.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (5.8.1)
# Requirement already satisfied: pyzmq>=24 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (27.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (1.8.14)
# Requirement already satisfied: tornado>=6.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (6.5.1)
# Requirement already satisfied: comm>=0.1.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: ipython>=7.23.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (8.37.0)
# Requirement already satisfied: nest-asyncio in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: psutil in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 9)) (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from plotly>=5.0.0->-r requirements.txt (line 10)) (1.45.0)
# Requirement already satisfied: colorama in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tqdm>=4.62.0->-r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: namex in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from keras>=2.8.0->-r requirements.txt (line 13)) (0.1.0)
# Requirement already satisfied: rich in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from keras>=2.8.0->-r requirements.txt (line 13)) (14.0.0)
# Requirement already satisfied: optree in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from keras>=2.8.0->-r requirements.txt (line 13)) (0.16.0)
# Requirement already satisfied: soundfile>=0.12.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (0.13.1)
# Requirement already satisfied: audioread>=2.1.9 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (3.0.1)
# Requirement already satisfied: soxr>=0.3.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (0.5.0.post1)
# Requirement already satisfied: numba>=0.51.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (0.61.2)
# Requirement already satisfied: decorator>=4.3.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from librosa>=0.8.0->-r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.45.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (3.0.51)
# Requirement already satisfied: exceptiongroup in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: stack_data in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: pywin32>=300 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r requirements.txt (line 9)) (310)
# Requirement already satisfied: platformdirs>=2.5 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r requirements.txt (line 9)) (4.3.8)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from numba>=0.51.0->librosa>=0.8.0->-r requirements.txt (line 14)) (0.44.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (2025.6.15)
# Requirement already satisfied: cffi>=1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from soundfile>=0.12.1->librosa>=0.8.0->-r requirements.txt (line 14)) (1.17.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow>=2.8.0->-r requirements.txt (line 6)) (3.8.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 8)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.0.15)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.16.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: notebook-shim>=0.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.2.4)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.27.3)
# Requirement already satisfied: tomli>=1.2.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: jinja2>=3.0.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: defusedxml in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: nbformat>=5.7 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: jupyterlab-pygments in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: bleach[css]!=5.0.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: markupsafe>=2.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (4.13.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from rich->keras>=2.8.0->-r requirements.txt (line 13)) (3.0.0)
# Requirement already satisfied: webencodings in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.4.0)
# Requirement already satisfied: pycparser in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.8.0->-r requirements.txt (line 14)) (2.22)
# Requirement already satisfied: httpcore==1.* in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: anyio in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: h11>=0.16 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.0.15)
# Requirement already satisfied: websocket-client>=1.7 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: send2trash>=1.8.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.8.3)
# Requirement already satisfied: prometheus-client>=0.9 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: terminado>=0.8.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: overrides>=5.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (7.7.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: babel>=2.10 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.17.0)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (4.24.0)
# Requirement already satisfied: json5>=0.9.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.8.0->-r requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.21.1)
# Requirement already satisfied: wcwidth in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.7)
# Requirement already satisfied: pure-eval in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: sniffio>=1.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (21.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.26.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2025.4.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (25.3.0)
# Requirement already satisfied: referencing>=0.28.4 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.36.2)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: rfc3339-validator in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: isoduration in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (20.11.0)
# Requirement already satisfied: uri-template in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: fqdn in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: arrow>=0.15.0 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\personal\ai-admissions\semester 3\aai-511 - neural networks and deep learning\final team project\aai_511_2proj\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 8)) (2.9.0.20250516)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import necessary libraries
import sys
import os
import shutil
import joblib
import hashlib
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# Music processing libraries
import music21
from music21 import converter, midi, tempo, key, instrument, note, chord, stream
import librosa
import librosa.display

# Deep learning libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D, Flatten, Embedding, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Reshape, GlobalAveragePooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

sys.path.append(os.path.abspath(os.path.join(os.pardir, 'src')))

np.random.seed(42)
tf.random.set_seed(42)
sns.set(style='whitegrid')
warnings.filterwarnings("ignore")
plt.style.use('default')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
data_dir = "data/midiclassics"
target_composers = ['Bach', 'Beethoven', 'Chopin', 'Mozart']

# %%
class MidiProcessor:

    def load_midi_files(self, data_dir, max_files_per_composer=None, n_jobs=8):
        all_files = []
        composers = [c for c in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, c))]
        def process_composer(composer):
            composer_path = os.path.join(data_dir, composer)
            midi_files = [f for f in os.listdir(composer_path) if f.endswith('.mid')]
            if max_files_per_composer:
                midi_files = midi_files[:max_files_per_composer]
            return [
                {
                    'file_path': os.path.join(composer_path, midi_file),
                    'composer': composer,
                    'filename': midi_file
                }
                for midi_file in midi_files
            ]
        with ThreadPoolExecutor(max_workers=n_jobs) as executor:
            futures = [executor.submit(process_composer, composer) for composer in composers]
            for f in as_completed(futures):
                all_files.extend(f.result())
        return pd.DataFrame(all_files)

    @staticmethod
    def extract_notes_from_midi(midi_path, max_notes=500):
        try:
            midi = converter.parse(midi_path)
            notes_to_parse = []
            if hasattr(midi, 'parts'):
                for part in midi.parts:
                    notes_to_parse.extend(part.recurse().notes)
            else:
                notes_to_parse = midi.flat.notes
            notes = []
            for element in notes_to_parse:
                if isinstance(element, note.Note):
                    notes.append(str(element.pitch))
                elif isinstance(element, chord.Chord):
                    notes.append('.'.join(str(n) for n in element.normalOrder))
            if len(notes) > max_notes:
                notes = notes[:max_notes]
            return notes
        except Exception as e:
            print(f"Error processing {midi_path}: {str(e)}")
            return []

    @staticmethod
    def extract_notes_from_midi_parallel(midi_paths, max_notes=500, n_jobs=8):
        results = [None] * len(midi_paths)
        def worker(idx, midi_path):
            results[idx] = MidiProcessor.extract_notes_from_midi(midi_path, max_notes)
        with ThreadPoolExecutor(max_workers=n_jobs) as executor:
            futures = [executor.submit(worker, idx, path) for idx, path in enumerate(midi_paths)]
            for _ in as_completed(futures):
                pass
        return results

    @staticmethod
    def extract_musical_features(midi_path):
        try:
            midi = converter.parse(midi_path)
            features = {}
            features['total_notes'] = len(midi.flat.notes)
            features['total_duration'] = float(midi.duration.quarterLength) if midi.duration else 0

            # Time signature
            time_sigs = midi.getTimeSignatures()
            if time_sigs:
                features['time_signature'] = f"{time_sigs[0].numerator}/{time_sigs[0].denominator}"
            else:
                features['time_signature'] = "4/4"

            # Key
            key_sigs = midi.analyze('key')
            features['key'] = str(key_sigs) if key_sigs else "C major"
            if hasattr(key_sigs, 'correlationCoefficient'):
                features['key_confidence'] = float(abs(key_sigs.correlationCoefficient))
            else:
                features['key_confidence'] = None

            # Tempo
            tempo_markings = midi.flat.getElementsByClass('MetronomeMark')
            if tempo_markings:
                features['tempo'] = float(tempo_markings[0].number)
            else:
                features['tempo'] = 120.0

            # Pitch features
            pitches = [n.pitch.midi for n in midi.flat.notes if isinstance(n, note.Note)]
            if pitches:
                features['avg_pitch'] = np.mean(pitches)
                features['pitch_range'] = max(pitches) - min(pitches)
                features['pitch_std'] = np.std(pitches)
            else:
                features['avg_pitch'] = 60
                features['pitch_range'] = 0
                features['pitch_std'] = 0

            # Duration features
            durations = [float(n.duration.quarterLength) for n in midi.flat.notes if n.duration]
            if durations:
                features['avg_duration'] = np.mean(durations)
                features['duration_std'] = np.std(durations)
            else:
                features['avg_duration'] = 1.0
                features['duration_std'] = 0

            # Interval features
            intervals = []
            prev_pitch = None
            for n in midi.flat.notes:
                if isinstance(n, note.Note):
                    if prev_pitch is not None:
                        intervals.append(abs(n.pitch.midi - prev_pitch))
                    prev_pitch = n.pitch.midi
            if intervals:
                features['avg_interval'] = np.mean(intervals)
                features['interval_std'] = np.std(intervals)
            else:
                features['avg_interval'] = 0
                features['interval_std'] = 0

            # Instrumentation
            instruments_list = []
            for part in midi.parts:
                instr = part.getInstrument(returnDefault=True)
                instruments_list.append(str(instr))
            features['instruments'] = list(set(instruments_list))

            # Number of parts/tracks
            features['num_parts'] = len(midi.parts)

            # Measure and beat features
            measures = list(midi.parts[0].getElementsByClass('Measure')) if midi.parts else []
            features['num_measures'] = len(measures)
            features['avg_notes_per_measure'] = features['total_notes'] / len(measures) if measures else 0

            # Chord features
            chords = [el for el in midi.flat.notesAndRests if isinstance(el, chord.Chord)]
            features['num_chords'] = len(chords)
            features['chord_types'] = list(set([c.commonName for c in chords])) if chords else []

            # Rest features
            rests = [el for el in midi.flat.notesAndRests if isinstance(el, note.Rest)]
            features['num_rests'] = len(rests)
            features['rest_ratio'] = len(rests) / features['total_notes'] if features['total_notes'] > 0 else 0

            return features
        except Exception as e:
            print(f"Error extracting features from {midi_path}: {str(e)}")
            return {}

    @staticmethod
    def extract_musical_features_parallel(midi_paths, n_jobs=8):
        results = [None] * len(midi_paths)
        def worker(idx, midi_path):
            results[idx] = MidiProcessor.extract_musical_features(midi_path)
        with ThreadPoolExecutor(max_workers=n_jobs) as executor:
            futures = [executor.submit(worker, idx, path) for idx, path in enumerate(midi_paths)]
            for _ in as_completed(futures):
                pass
        return results

    @staticmethod
    def create_note_sequences(notes_list, sequence_length=100):
        sequences = []
        all_notes = []
        for notes in notes_list:
            all_notes.extend(notes)
        unique_notes = sorted(set(all_notes))
        note_to_int = {note: i for i, note in enumerate(unique_notes)}
        for notes in notes_list:
            if len(notes) >= sequence_length:
                note_ints = [note_to_int[note] for note in notes if note in note_to_int]
                for i in range(len(note_ints) - sequence_length + 1):
                    sequences.append(note_ints[i:i + sequence_length])
        return np.array(sequences), note_to_int, unique_notes

    @staticmethod
    def preprocess_midi_files(file_df, min_duration=5.0, min_key_confidence=0.7, verbose=True, n_jobs=8):
        processed_files = []
        seen_hashes = set()
        total = len(file_df)
        stats = {
            'total': total,
            'corrupted': 0,
            'zero_length': 0,
            'duplicates': 0,
            'too_short': 0,
            'ambiguous_key': 0,
            'kept': 0
        }

        def process_row(idx_row):
            idx, row = idx_row
            path = row['file_path']
            try:
                mf = midi.MidiFile()
                mf.open(path)
                mf.read()
                mf.close()
                if len(mf.tracks) == 0 or mf.ticksPerQuarterNote == 0:
                    return ('zero_length', None)
                with open(path, 'rb') as f:
                    file_hash = hashlib.md5(f.read()).hexdigest()
                # Deduplication will be handled after parallel processing
                score = converter.parse(path)
                duration = score.duration.seconds if score.duration else 0
                if duration < min_duration:
                    return ('too_short', None)
                tempos = list(score.flat.getElementsByClass(tempo.MetronomeMark))
                if tempos:
                    effective_bpm = float(np.median([t.number for t in tempos if t.number]))
                else:
                    effective_bpm = 120.0
                for t in tempos:
                    score.remove(t)
                score.insert(0, tempo.MetronomeMark(number=effective_bpm))
                key_obj = score.analyze('key')
                if hasattr(key_obj, 'correlationCoefficient'):
                    confidence = abs(key_obj.correlationCoefficient)
                else:
                    confidence = 1.0
                if confidence < min_key_confidence:
                    return ('ambiguous_key', None)
                parts = score.parts.stream()
                if len(parts) > 1:
                    score = parts[0]
                return ('kept', (file_hash, row))
            except Exception as e:
                return ('corrupted', None)

        completed = 0
        with ThreadPoolExecutor(max_workers=n_jobs) as executor:
            futures = [executor.submit(process_row, (idx, row)) for idx, row in file_df.iterrows()]
            for f in as_completed(futures):
                result, data = f.result()
                completed += 1
                percent = (completed / total) * 100
                if verbose:
                    print(f"\rProcessing: {completed}/{total} ({percent:.1f}%)", end='', flush=True)
                if result == 'kept' and data:
                    file_hash, row = data
                    if file_hash in seen_hashes:
                        stats['duplicates'] += 1
                        continue
                    seen_hashes.add(file_hash)
                    processed_files.append(row)
                    stats['kept'] += 1
                else:
                    stats[result] += 1
        if verbose:
            print()  # Move to next line after progress bar
            print("Preprocessing MIDI files:")
            print(f"Total files: {stats['total']}")
            print(f"Corrupted files: {stats['corrupted']}")
            print(f"Zero-length files: {stats['zero_length']}")
            print(f"Duplicates: {stats['duplicates']}")
            print(f"Too short (<{min_duration}s): {stats['too_short']}")
            print(f"Ambiguous key: {stats['ambiguous_key']}")
            print(f"Kept: {stats['kept']}")

        return pd.DataFrame(processed_files)

# %%
# Initialize MidiProcessor
midi_processor = MidiProcessor()

# Load MIDI file metadata into a DataFrame
all_midi_df = midi_processor.load_midi_files(data_dir)

print(f"Total MIDI files found: {len(all_midi_df)}")

# Filter for required composers only
midi_df = all_midi_df[all_midi_df['composer'].isin(target_composers)].reset_index(drop=True)

print(f"Filtered MIDI files for target composers ({len(target_composers)}): {len(midi_df)}")

# Remove files with missing or invalid paths
midi_df = midi_df[midi_df['file_path'].apply(os.path.exists)].reset_index(drop=True)

# Preprocess MIDI files (clean, deduplicate, filter)
midi_df = midi_processor.preprocess_midi_files(midi_df)

print(f"Valid MIDI files after preprocessing: {len(midi_df)}")

# Count files for all composers and required composers
all_composer_counts = all_midi_df['composer'].value_counts()
required_composer_counts = midi_df['composer'].value_counts()

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1: Top 15 composers
top_composers = all_composer_counts.head(15)
top_composers.plot(kind='bar', color='lightgreen', ax=axs[0])
axs[0].set_title('Top 15 Composers')
axs[0].set_xlabel('Composer')
axs[0].set_ylabel('Number of Files')
axs[0].tick_params(axis='x', rotation=45)

# Plot 2: Required composers only
required_composer_counts.plot(kind='bar', color='orange', ax=axs[1])
axs[1].set_title('Target Composers')
axs[1].set_xlabel('Composer')
axs[1].set_ylabel('Number of Files')
axs[1].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()
# Out:
# Total MIDI files found: 1785
# Filtered MIDI files for target composers (4): 481
# Processing: 212/481 (44.1%)

# %% [markdown]
# <a id='featureextraction'></a>
# # 5. Feature Extraction: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %%
# Extract musical features and notes for each MIDI file and create a new DataFrame
feature_rows = []
total_files = len(midi_df)
for idx, row in midi_df.iterrows():
    percent = ((idx + 1) / total_files) * 100
    print(f"Processing: {percent:.1f}% complete", end='\r')
    features = midi_processor.extract_musical_features(row['file_path'])
    notes = midi_processor.extract_notes_from_midi(row['file_path'])
    features['notes'] = notes
    features['composer'] = row['composer']
    features['filename'] = row['filename']
    feature_rows.append(features)

print("\nExtraction complete.")
features_df = pd.DataFrame(feature_rows)
print(features_df.head())

# Create note sequences for modeling
all_notes_list = features_df['notes'].tolist()
sequence_length = 100
note_sequences, note_to_int, unique_notes = MidiProcessor.create_note_sequences(all_notes_list, sequence_length=sequence_length)
print(f"Total note sequences created: {len(note_sequences)}")

# %% [markdown]
# <a id='exploratory'></a>
# # 6. Exploratory Data Analysis: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modelbuilding'></a>
# # 7. Model Building: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modelbuildinglstm'></a>
# ## 7.1 Long Short-Term Memory (LSTM): <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modelselectioncnn'></a>
# ## 7.2 Convolutional Neural Network (CNN): <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modeltraining'></a>
# # 8. Model Training: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modelevaluation'></a>
# # 9. Model Evaluation: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='modeloptimiztion'></a>
# # 10. Model Optimization: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='deployment'></a>
# # 11. Deployment: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='conclusion'></a>
# # 12. Conclusion: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='recommendations'></a>
# # 13. Recommendations: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='nextsteps'></a>
# # 14. Next Steps: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---

# %% [markdown]
# <a id='references'></a>
# # 15. References: <a href="#Index" style="font-size:25px;">&#8679;</a>
# ---
